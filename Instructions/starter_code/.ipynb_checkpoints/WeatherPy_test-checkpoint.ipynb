# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# %pip install citipy
# Out:
# Collecting citipy
#   Downloading citipy-0.0.5.tar.gz (557 kB)
#      |████████████████████████████████| 557 kB 45 kB/s eta 0:00:013
# Collecting kdtree>=0.12
#   Downloading kdtree-0.16-py2.py3-none-any.whl (7.7 kB)
# Building wheels for collected packages: citipy
#   Building wheel for citipy (setup.py) ... done
#   Created wheel for citipy: filename=citipy-0.0.5-py3-none-any.whl size=559701 sha256=c4ae357e27e2a3fb30e907aa2a5afe69e28231dc47de5c11de1534267bd97403
#   Stored in directory: /Users/joshmaldo/Library/Caches/pip/wheels/6d/df/5e/ad8eb9cc5ee7f4ba76865167c09f9a7edff405c669111d8353
# Successfully built citipy
# Installing collected packages: kdtree, citipy
# Successfully installed citipy-0.0.5 kdtree-0.16
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
# lat_range = (-90, 90)
# lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 643

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Set up empty variables for needed information
City = []
Lat = []
Lng = []
Max_Temp = []
Cloudiness = []
Humidity = []
Wind_Speed = []
Country = []
Date = []

# Setting up for count
count=1

# Setting up the URL for Temp in F - this was obtained from API sit documentation
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid="+weather_api_key+"&q="

# Setting up header as suggested in example shown
print("Beginning Data Retrieval")
print("-----------------------------")

# Setting up loop for the retrieval of cities
for city in cities:
    # Using query url to include each city
    query_url = url + city
    # Setting up try statement to avoid error and appending all list for data
    try:
        response = requests.get(query_url).json()
        City.append(response['name'])
        Lat.append(response['coord']['lat'])
        Lng.append(response['coord']['lon'])
        Max_Temp.append(response['main']['temp_max'])
        Cloudiness.append(response['clouds']['all'])
        Humidity.append(response['main']['humidity'])
        Wind_Speed.append(response['wind']['speed'])
        Country.append(response['sys']['country'])
        Date.append(response['dt'])
        # Set up processing statement for query
        print(f'Processing City {count} of {len(cities)} | {city} ')
        # Formula to increase count
        count = count + 1
    except KeyError:
        print(f'City Not Found. Skipping...')
# Printing line for end of loop
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing City 1 of 643 | los llanos de aridane
# City Not Found. Skipping...
# Processing City 2 of 643 | provideniya
# Processing City 3 of 643 | avarua
# Processing City 4 of 643 | rikitea
# Processing City 5 of 643 | bambous virieux
# Processing City 6 of 643 | hambantota
# Processing City 7 of 643 | chaman
# Processing City 8 of 643 | cosala
# Processing City 9 of 643 | bredasdorp
# Processing City 10 of 643 | jambi
# Processing City 11 of 643 | oxbow
# Processing City 12 of 643 | afsin
# Processing City 13 of 643 | barrow
# Processing City 14 of 643 | hermanus
# Processing City 15 of 643 | mataura
# Processing City 16 of 643 | assomada
# Processing City 17 of 643 | touros
# Processing City 18 of 643 | beringovskiy
# Processing City 19 of 643 | vaini
# Processing City 20 of 643 | albany
# Processing City 21 of 643 | cape town
# Processing City 22 of 643 | airai
# Processing City 23 of 643 | westport
# Processing City 24 of 643 | songea
# Processing City 25 of 643 | lebu
# Processing City 26 of 643 | merauke
# Processing City 27 of 643 | labytnangi
# City Not Found. Skipping...
# Processing City 28 of 643 | mwinilunga
# Processing City 29 of 643 | upernavik
# Processing City 30 of 643 | butaritari
# Processing City 31 of 643 | port lincoln
# Processing City 32 of 643 | santa isabel
# Processing City 33 of 643 | calvinia
# Processing City 34 of 643 | dikson
# Processing City 35 of 643 | khatanga
# Processing City 36 of 643 | jamestown
# Processing City 37 of 643 | yellowknife
# City Not Found. Skipping...
# Processing City 38 of 643 | japura
# Processing City 39 of 643 | krasnoselkup
# Processing City 40 of 643 | carnarvon
# Processing City 41 of 643 | sampit
# Processing City 42 of 643 | kobrinskoye
# Processing City 43 of 643 | nikolskoye
# Processing City 44 of 643 | punta arenas
# Processing City 45 of 643 | ushuaia
# Processing City 46 of 643 | kuandian
# Processing City 47 of 643 | vilyuysk
# Processing City 48 of 643 | shakhovskaya
# City Not Found. Skipping...
# Processing City 49 of 643 | kruisfontein
# Processing City 50 of 643 | faanui
# Processing City 51 of 643 | hualmay
# Processing City 52 of 643 | lusambo
# City Not Found. Skipping...
# Processing City 53 of 643 | arraial do cabo
# Processing City 54 of 643 | mar del plata
# Processing City 55 of 643 | prado
# Processing City 56 of 643 | vila franca do campo
# Processing City 57 of 643 | bluff
# Processing City 58 of 643 | victoria
# Processing City 59 of 643 | sur
# Processing City 60 of 643 | isangel
# Processing City 61 of 643 | lensk
# Processing City 62 of 643 | saint-francois
# Processing City 63 of 643 | sao filipe
# Processing City 64 of 643 | saint george
# Processing City 65 of 643 | atuona
# Processing City 66 of 643 | kodiak
# Processing City 67 of 643 | bambanglipuro
# Processing City 68 of 643 | sorland
# Processing City 69 of 643 | muscat
# City Not Found. Skipping...
# Processing City 70 of 643 | saint simons
# Processing City 71 of 643 | mahebourg
# Processing City 72 of 643 | sechura
# Processing City 73 of 643 | faya
# Processing City 74 of 643 | hobart
# Processing City 75 of 643 | qaanaaq
# Processing City 76 of 643 | muzhi
# Processing City 77 of 643 | puerto ayora
# Processing City 78 of 643 | cherskiy
# Processing City 79 of 643 | saskylakh
# Processing City 80 of 643 | espoo
# Processing City 81 of 643 | yar-sale
# Processing City 82 of 643 | cockburn town
# Processing City 83 of 643 | port blair
# Processing City 84 of 643 | bathsheba
# Processing City 85 of 643 | ngunguru
# Processing City 86 of 643 | geraldton
# Processing City 87 of 643 | deputatskiy
# Processing City 88 of 643 | mao
# Processing City 89 of 643 | klyuchi
# Processing City 90 of 643 | ribeira grande
# Processing City 91 of 643 | port hedland
# Processing City 92 of 643 | quatre cocos
# City Not Found. Skipping...
# Processing City 93 of 643 | port alfred
# Processing City 94 of 643 | bengkulu
# Processing City 95 of 643 | marystown
# Processing City 96 of 643 | lahat
# Processing City 97 of 643 | east london
# Processing City 98 of 643 | laguna
# Processing City 99 of 643 | klaksvik
# City Not Found. Skipping...
# Processing City 100 of 643 | busselton
# Processing City 101 of 643 | dehloran
# Processing City 102 of 643 | jacqueville
# Processing City 103 of 643 | acajutla
# Processing City 104 of 643 | cabo san lucas
# Processing City 105 of 643 | vila velha
# Processing City 106 of 643 | ponta do sol
# Processing City 107 of 643 | rocha
# Processing City 108 of 643 | dublyany
# Processing City 109 of 643 | grimshaw
# City Not Found. Skipping...
# Processing City 110 of 643 | new norfolk
# Processing City 111 of 643 | hilo
# Processing City 112 of 643 | bangassou
# City Not Found. Skipping...
# Processing City 113 of 643 | bonavista
# Processing City 114 of 643 | sayyan
# City Not Found. Skipping...
# City Not Found. Skipping...
# Processing City 347 of 643 | brae
# Processing City 348 of 643 | rosarito
# Processing City 349 of 643 | praia
# Processing City 350 of 643 | atar
# Processing City 351 of 643 | buraydah
# Processing City 352 of 643 | ketchikan
# Processing City 353 of 643 | olafsvik
# Processing City 354 of 643 | fairbanks
# Processing City 355 of 643 | soc trang
# Processing City 356 of 643 | varna
# Processing City 357 of 643 | bantry
# Processing City 358 of 643 | bandarbeyla
# Processing City 359 of 643 | wanning
# Processing City 360 of 643 | ouesso
# Processing City 361 of 643 | pevek
# Processing City 362 of 643 | nikolayevka
# Processing City 363 of 643 | tombouctou
# Processing City 364 of 643 | pathein
# Processing City 365 of 643 | chiredzi
# Processing City 366 of 643 | talnakh
# Processing City 367 of 643 | pasighat
# Processing City 368 of 643 | ganjam
# Processing City 369 of 643 | necochea
# Processing City 370 of 643 | aswan
# Processing City 371 of 643 | antofagasta
# Processing City 372 of 643 | atasu
# Processing City 373 of 643 | mayumba
# Processing City 374 of 643 | ihosy
# Processing City 375 of 643 | kieta
# Processing City 376 of 643 | kharp
# Processing City 377 of 643 | hayden
# Processing City 378 of 643 | jalu
# Processing City 379 of 643 | brazzaville
# Processing City 380 of 643 | ustka
# Processing City 381 of 643 | mitu
# City Not Found. Skipping...
# Processing City 382 of 643 | tilichiki
# Processing City 383 of 643 | raudeberg
# Processing City 384 of 643 | high river
# Processing City 385 of 643 | husavik
# Processing City 386 of 643 | dragoman
# Processing City 387 of 643 | yuli
# Processing City 388 of 643 | skibbereen
# Processing City 389 of 643 | kattivakkam
# Processing City 390 of 643 | marfino
# Processing City 391 of 643 | lavrentiya
# Processing City 392 of 643 | san julian
# Processing City 393 of 643 | ellisras
# Processing City 394 of 643 | naze
# Processing City 395 of 643 | tyukhtet
# Processing City 396 of 643 | doha
# Processing City 397 of 643 | beyneu
# Processing City 398 of 643 | lalibela
# Processing City 399 of 643 | tukrah
# Processing City 400 of 643 | peniche
# Processing City 401 of 643 | bethel
# City Not Found. Skipping...
# Processing City 402 of 643 | awjilah
# Processing City 403 of 643 | suraabad
# Processing City 404 of 643 | soure
# Processing City 405 of 643 | aberdeen
# Processing City 406 of 643 | saint-georges
# City Not Found. Skipping...
# Processing City 407 of 643 | dryden
# Processing City 408 of 643 | stornoway
# Processing City 409 of 643 | cafarnaum
# Processing City 410 of 643 | gigmoto
# Processing City 411 of 643 | boguchany
# Processing City 412 of 643 | caravelas
# Processing City 413 of 643 | san luis
# Processing City 414 of 643 | kiama
# Processing City 415 of 643 | ongandjera
# City Not Found. Skipping...
# Processing City 416 of 643 | chauk
# Processing City 417 of 643 | chumikan
# Processing City 418 of 643 | luderitz
# Processing City 419 of 643 | karauli
# Processing City 420 of 643 | kirakira
# Processing City 421 of 643 | boddam
# Processing City 422 of 643 | nchelenge
# Processing City 423 of 643 | assemini
# Processing City 424 of 643 | laurel
# Processing City 425 of 643 | lufilufi
# Processing City 426 of 643 | bejar
# Processing City 427 of 643 | biak
# Processing City 428 of 643 | barkly west
# Processing City 429 of 643 | solhan
# Processing City 430 of 643 | porto walter
# Processing City 431 of 643 | balkhash
# Processing City 432 of 643 | chernenko
# Processing City 433 of 643 | koscierzyna
# Processing City 434 of 643 | cayenne
# Processing City 435 of 643 | la rioja
# Processing City 436 of 643 | ostrovnoy
# Processing City 437 of 643 | san carlos
# Processing City 438 of 643 | rorvik
# Processing City 439 of 643 | mattoon
# Processing City 440 of 643 | coihaique
# Processing City 441 of 643 | gat
# Processing City 442 of 643 | berlevag
# Processing City 443 of 643 | gold coast
# Processing City 444 of 643 | eureka
# Processing City 445 of 643 | nemuro
# Processing City 446 of 643 | hispania
# Processing City 447 of 643 | pangnirtung
# Processing City 448 of 643 | hasaki
# Processing City 449 of 643 | kawalu
# Processing City 450 of 643 | sitka
# Processing City 451 of 643 | hwange
# Processing City 452 of 643 | nabire
# Processing City 453 of 643 | chicama
# Processing City 454 of 643 | mount gambier
# Processing City 455 of 643 | georgetown
# Processing City 456 of 643 | cozumel
# Processing City 457 of 643 | viytivka
# City Not Found. Skipping...
# Processing City 458 of 643 | kautokeino
# Processing City 459 of 643 | celestun
# Processing City 460 of 643 | nisia floresta
# Processing City 461 of 643 | chirongui
# Processing City 462 of 643 | nouakchott
# Processing City 463 of 643 | boralday
# Processing City 464 of 643 | kabo
# Processing City 465 of 643 | puri
# Processing City 466 of 643 | tshikapa
# Processing City 467 of 643 | wilmington
# Processing City 468 of 643 | aloleng
# Processing City 469 of 643 | ugoofaaru
# Processing City 470 of 643 | hohhot
# Processing City 471 of 643 | ternate
# Processing City 472 of 643 | muros
# Processing City 473 of 643 | krasnoshchekovo
# Processing City 474 of 643 | lere
# City Not Found. Skipping...
# Processing City 475 of 643 | formosa
# Processing City 476 of 643 | sangmelima
# City Not Found. Skipping...
# Processing City 477 of 643 | ancud
# Processing City 478 of 643 | sovetskiy
# Processing City 479 of 643 | tokonou
# City Not Found. Skipping...
# Processing City 480 of 643 | capitao poco
# Processing City 481 of 643 | mehran
# City Not Found. Skipping...
# Processing City 482 of 643 | freeport
# Processing City 483 of 643 | severobaykalsk
# Processing City 484 of 643 | kavaratti
# Processing City 485 of 643 | hobyo
# City Not Found. Skipping...
# Processing City 486 of 643 | verkhnyaya inta
# Processing City 487 of 643 | portobelo
# Processing City 488 of 643 | souillac
# Processing City 489 of 643 | nassjo
# Processing City 490 of 643 | manono
# Processing City 491 of 643 | saldanha
# Processing City 492 of 643 | punta alta
# Processing City 493 of 643 | iqaluit
# Processing City 494 of 643 | tateyama
# Processing City 495 of 643 | rio grande
# Processing City 496 of 643 | manta
# Processing City 497 of 643 | deming
# City Not Found. Skipping...
# Processing City 498 of 643 | de aar
# Processing City 499 of 643 | morondava
# Processing City 500 of 643 | nyrob
# Processing City 501 of 643 | praia da vitoria
# Processing City 502 of 643 | kuching
# Processing City 503 of 643 | the pas
# Processing City 504 of 643 | havoysund
# Processing City 505 of 643 | syumsi
# Processing City 506 of 643 | camana
# Processing City 507 of 643 | margate
# Processing City 508 of 643 | yershov
# Processing City 509 of 643 | huarmey
# Processing City 510 of 643 | kupang
# Processing City 511 of 643 | filingue
# Processing City 512 of 643 | ciudad valles
# Processing City 513 of 643 | monrovia
# Processing City 514 of 643 | bloomsburg
# Processing City 515 of 643 | oranjemund
# Processing City 516 of 643 | eyl
# Processing City 517 of 643 | rozivka
# Processing City 518 of 643 | palembang
# Processing City 519 of 643 | soyo
# Processing City 520 of 643 | leshukonskoye
# Processing City 521 of 643 | romanovo
# Processing City 522 of 643 | adeje
# Processing City 523 of 643 | ribeira brava
# Processing City 524 of 643 | zhuzhou
# Processing City 525 of 643 | catamarca
# Processing City 526 of 643 | oyama
# Processing City 527 of 643 | kamen-rybolov
# Processing City 528 of 643 | maceio
# Processing City 529 of 643 | honiara
# Processing City 530 of 643 | laives
# Processing City 531 of 643 | krasnyy oktyabr
# Processing City 532 of 643 | dauriya
# Processing City 533 of 643 | cervo
# Processing City 534 of 643 | wronki
# Processing City 535 of 643 | ambon
# Processing City 536 of 643 | marrakesh
# Processing City 537 of 643 | tumut
# Processing City 538 of 643 | dnipryany
# Processing City 539 of 643 | pafos
# Processing City 540 of 643 | kununurra
# Processing City 541 of 643 | pauini
# Processing City 542 of 643 | markapur
# Processing City 543 of 643 | aldan
# Processing City 544 of 643 | bardiyah
# Processing City 545 of 643 | sydney
# Processing City 546 of 643 | aklavik
# Processing City 547 of 643 | kuala sungai baru
# City Not Found. Skipping...
# Processing City 548 of 643 | morgan city
# Processing City 549 of 643 | ryotsu
# Processing City 550 of 643 | glyadyanskoye
# Processing City 551 of 643 | korla
# Processing City 552 of 643 | suntar
# Processing City 553 of 643 | standerton
# Processing City 554 of 643 | crotone
# Processing City 555 of 643 | amahai
# Processing City 556 of 643 | san cristobal
# Processing City 557 of 643 | abha
# Processing City 558 of 643 | nuuk
# Processing City 559 of 643 | pravia
# Processing City 560 of 643 | kyren
# Processing City 561 of 643 | ojinaga
# Processing City 562 of 643 | zarya
# Processing City 563 of 643 | tamandare
# Processing City 564 of 643 | tianpeng
# Processing City 565 of 643 | burnie
# City Not Found. Skipping...
# Processing City 566 of 643 | rawson
# Processing City 567 of 643 | mingyue
# Processing City 568 of 643 | teya
# Processing City 569 of 643 | chapais
# Processing City 570 of 643 | tauranga
# Processing City 571 of 643 | hami
# Processing City 572 of 643 | itoman
# Processing City 573 of 643 | kargasok
# Processing City 574 of 643 | leopoldov
# Processing City 575 of 643 | lukovetskiy
# Processing City 576 of 643 | auki
# Processing City 577 of 643 | nagorsk
# Processing City 578 of 643 | pacific grove
# Processing City 579 of 643 | roald
# Processing City 580 of 643 | vao
# Processing City 581 of 643 | coromandel
# Processing City 582 of 643 | mfou
# Processing City 583 of 643 | pailon
# City Not Found. Skipping...
# Processing City 584 of 643 | ariquemes
# Processing City 585 of 643 | fare
# Processing City 586 of 643 | lewiston
# Processing City 587 of 643 | myitkyina
# Processing City 588 of 643 | goderich
# Processing City 589 of 643 | bhadrachalam
# Processing City 590 of 643 | cerritos
# Processing City 591 of 643 | tuxpan
# Processing City 592 of 643 | oriximina
# Processing City 593 of 643 | asfi
# Processing City 594 of 643 | oshawa
# Processing City 595 of 643 | viedma
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Putting together dictionary of info collected
weather_dict = {"City": City,
               "Lat": Lat,
               "Lng": Lng,
               "Max Temp (F)": Max_Temp,
               "Cloudiness": Cloudiness,
               "Humidity": Humidity,
               "Wind Speed": Wind_Speed,
               "Country": Country,
               "Date": Date}
# Creating data frame from dict
weather_info = pd.DataFrame(weather_dict)
weather_info.head()
# Out:
#                     City      Lat       Lng  Max Temp (F)  Cloudiness  \
# 0  Los Llanos de Aridane  28.6585  -17.9182         64.40           0
# 1            Provideniya  64.3833 -173.3000         32.00          90
# 2                 Avarua -21.2078 -159.7750         82.40          87
# 3                Rikitea -23.1203 -134.9692         76.96         100
# 4        Bambous Virieux -20.3428   57.7575         77.00          75
#
#    Humidity  Wind Speed Country        Date
# 0        63        5.75      ES  1619578636
# 1        80        6.71      RU  1619578637
# 2        74        6.91      CK  1619578637
# 3        74       11.99      PF  1619578382
# 4        88       11.50      MU  1619578638

# %%
# Exporting data frame to csv file
# weather_info.to_csv("../output_data/weather_info.csv", index=False)

# Ensuring data frame was exported
weather_df = pd.read_csv("../output_data/weather_info.csv")
weather_df.head()
# Out:
#                     City      Lat       Lng  Max Temp (F)  Cloudiness  \
# 0  Los Llanos de Aridane  28.6585  -17.9182         64.40           0
# 1            Provideniya  64.3833 -173.3000         32.00          90
# 2                 Avarua -21.2078 -159.7750         82.40          87
# 3                Rikitea -23.1203 -134.9692         76.96         100
# 4        Bambous Virieux -20.3428   57.7575         77.00          75
#
#    Humidity  Wind Speed Country        Date
# 0        63        5.75      ES  1619578636
# 1        80        6.71      RU  1619578637
# 2        74        6.91      CK  1619578637
# 3        74       11.99      PF  1619578382
# 4        88       11.50      MU  1619578638

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Searching for possible cities with >100% Humidity
humid100 = weather_df.loc[weather_df["Humidity"]>100]
humid100
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp (F), Cloudiness, Humidity, Wind Speed, Country, Date]
# Index: []

# %%
#  No cities were found with >100% Humidity

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
weather_df.plot(kind='scatter', x="Lat", y="Max Temp (F)", edgecolors='k', s=30, grid=True)
plt.title("City Latitude vs. Max Temperature (5/27/2021)")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
plt.savefig("../Images/city_latvsmaxtemp.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
weather_df.plot(kind='scatter', x="Lat", y="Humidity", edgecolors='k', s=30, grid=True)
plt.title("City Latitude vs. Humidity (5/27/2021)")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.savefig("../Images/city_latvshumidity.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
weather_df.plot(kind='scatter', x="Lat", y="Cloudiness", edgecolors='k', s=30, grid=True)
plt.title("City Latitude vs. Cloudiness (5/27/2021)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.savefig("../Images/city_latvscloudiness.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
weather_df.plot(kind='scatter', x="Lat", y="Wind Speed", edgecolors='k', s=30, grid=True)
plt.title("City Latitude vs. Wind Speed (5/27/2021)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.savefig("../Images/city_latvswindspeed.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.46937863826630627

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.6082708688906918

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.000543987878808455

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.014985174297345524

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0020898727664228514

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0035263772085582894

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.04019723576144484

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.017128274759839232
